# %% [markdown]
# <a href="https://colab.research.google.com/github/HIRO76/charts/blob/gh-pages/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
data = [8,17,0,11,6,21,16,6,17,11,7,9,6,13,12,16,3,14,13,12]
print(f"平均値は{statistics.mean(data)}です。")
print(f"中央値は{statistics.median(data)}です。")
print(f"最頻値は{statistics.mode(data)}です。")
print(f"分散は{statistics.pvariance(data)}です。")
print(f"標準偏差は{statistics.pstdev(data)}です。")
# Out:
# 平均値は10.9です。
# 中央値は11.5です。
# 最頻値は6です。
# 分散は26.49です。
# 標準偏差は5.146843692983108です。

# %%
import matplotlib.pyplot as plt
data = [8,17,0,11,6,21,16,6,17,11,7,9,6,13,12,16,3,14,13,12]
# plt.rcParams["font.family"] = "HiraMinProN-W3"
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("frequency")
plt.hist(data)
plt.show()

# %%
import random 
import matplotlib.pyplot as plt
x = []
y = []
for i in range(100):
    x.append(random.uniform(0, 50))
    y.append(random.uniform(0, 50))
plt.scatter(x, y)
plt.show()

# %%
import math 
import matplotlib.pyplot as plt

x = []
s = []
c = []

for i in range(50):
    x.append(i*0.05*math.pi)
    s.append(math.sin(x[i]))
    c.append(math.cos(x[i]))

plt.title("sin/cos functions")
plt.xlabel("rad")
plt.ylabel("value")
plt.grid(True)

plt.plot(x, s, label="sin")
plt.plot(x, c, label="cos")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.0, 2.5, 0.05)*np.pi
s = np.sin(x)
c = np.cos(x)
plt.title("sin/cos functions")
plt.xlabel("rad")
plt.ylabel("value")
plt.grid(True)
plt.plot(x, s, label="sin")
plt.plot(x, c, label="cos")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
data = [8,17,0,11,6,21,16,6,17,11,7,9,6,13,12,16,3,14,13,12]
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("frequency")
plt.hist(data, histtype="step", bins=8, color="magenta")
plt.show()

# %%
import random
import matplotlib.pyplot as plt

x = [random.uniform(0,50) for n in range(100)]
y = [random.uniform(0,50) for n in range(100)]

plt.xlim(-100, 100)
plt.ylim(-100,100)
plt.scatter(x, y, marker="x")
plt.show()

# %%
import matplotlib.pyplot as plt 
import random 

data = [random.normalvariate(0,10) for n in range(1000)]
plt.title("Histogram")
plt.hist(data, bins=50)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-8, 8, 0.01)
y1 = 3*x+5
y2 = x**2

plt.title("y=f(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np 

np.random.seed(0)
x, y = datasets.make_regression(n_samples=100, n_features=1, noise=30)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
e = linear_model.LinearRegression()
e.fit(x_train, y_train)
print("回帰係数は", e.coef_, "です。")
print("切片は", e.intercept_, "です。")
y_pred = e.predict(x_test)
print("学習データによる決定係数は", e.score(x_train, y_train), "です。")
print("テストデータによる決定係数は", e.score(x_test, y_test), "です。")

plt.scatter(x_train, y_train, label="train")
plt.scatter(x_test, y_test, label="test")
plt.plot(x_test, y_pred, color="magenta")
plt.legend()
plt.show()
# Out:
# 回帰係数は [45.53155127] です。
# 切片は -5.4206693967270025 です。
# 学習データによる決定係数は 0.6920076270690864 です。
# テストデータによる決定係数は 0.5033443224342988 です。

# %%
from sklearn import datasets
from sklearn import cluster 
import matplotlib.pyplot as plt 

data, label = datasets.make_blobs(n_samples=500, n_features=2, centers=5)
e = cluster.KMeans(n_clusters=5)
e.fit(data)
# print(data)
# print(label)
print(e.labels_)
print(e.cluster_centers_)

plt.scatter(data[:,0], data[:,1], marker="o", c=e.labels_, edgecolor="k")
plt.scatter(e.cluster_centers_[:,0], e.cluster_centers_[:,1], marker="x")
plt.show()
# Out:
# [4 0 2 0 3 1 1 3 0 4 3 2 4 0 2 4 4 2 1 4 4 1 3 4 1 2 3 3 0 2 4 0 1 1 2 2 0
#  3 4 4 4 2 0 2 0 4 3 0 4 3 1 1 2 0 3 2 4 0 0 3 4 3 2 2 4 4 4 3 0 3 0 1 3 4
#  2 2 1 4 4 2 1 1 3 0 3 2 3 4 0 4 0 2 4 4 3 2 0 2 0 0 2 1 0 2 3 1 3 0 2 1 3
#  3 4 3 2 3 3 4 4 1 2 0 2 2 2 0 0 4 4 0 0 3 1 0 4 1 1 2 4 4 3 4 3 4 3 4 1 4
#  0 2 3 1 1 4 1 4 1 0 0 1 0 0 3 4 3 3 3 3 2 2 0 0 2 0 0 1 2 0 4 4 1 0 0 1 4
#  1 1 2 4 1 4 4 3 3 2 1 3 1 3 2 2 4 1 4 3 0 2 3 4 0 0 3 4 3 1 0 4 2 0 0 3 1
#  2 3 2 2 4 4 0 3 2 2 0 3 3 4 2 3 0 1 1 1 2 3 4 3 4 4 1 2 3 0 1 1 2 1 0 2 3
#  2 2 0 4 1 1 0 3 1 2 2 0 2 3 4 4 4 4 4 3 2 2 2 3 2 0 0 1 0 4 0 1 2 1 0 1 3
#  0 1 3 0 2 4 1 2 3 1 4 0 1 2 4 2 3 3 0 0 0 2 4 2 1 0 1 1 0 3 4 2 0 4 0 1 2
#  0 0 1 1 4 0 2 1 1 3 1 3 1 4 2 1 1 0 4 4 1 3 4 2 1 3 2 1 2 1 1 4 2 3 0 1 3
#  4 1 4 0 2 1 1 0 4 0 0 3 3 1 1 3 3 2 4 0 2 3 1 1 3 1 0 0 3 4 2 0 0 2 1 4 0
#  4 3 1 0 0 2 2 1 0 4 4 3 2 4 3 4 0 4 4 2 2 1 0 0 2 4 4 2 2 3 4 4 0 2 1 4 3
# ...

# %%
from sklearn import datasets
from sklearn import linear_model 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np 
np.random.seed(0)
x, y = datasets.make_regression(n_samples=300, n_features=1, noise=50)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
e = linear_model.LinearRegression()
e.fit(x_train, y_train)
y_pred = e.predict(x_test)
plt.scatter(x_train, y_train, label="train")
plt.scatter(x_test, y_test, label="test")
plt.plot(x_test, y_pred, color="magenta")
plt.legend()
plt.show()

# %%
from sklearn import datasets
from sklearn import cluster
import matplotlib.pyplot as plt
data, label = datasets.make_blobs(n_samples=1000, n_features=2, centers=10, cluster_std=3)
e = cluster.KMeans(n_clusters=8)
e.fit(data)
plt.scatter(data[:,0], data[:,1], marker="o", c=e.labels_, edgecolor="k")
plt.scatter(e.cluster_centers_[:,0], e.cluster_centers_[:,1], marker="x")
plt.show()

# %%
import matplotlib.pyplot as plt
data=[8,17,0,11,6,21,16,6,17,11,7,9,6,13,12,16,3,14,13,12]
plt.title("Histogram")
plt.xlabel("value")
plt.ylabel("frequency")
plt.hist(data, bins=8, color="magenta")
plt.show()

# %%
import random 
import matplotlib.pyplot as plt 
x = [random.uniform(0,50) for n in range(100)]
y = [random.uniform(0,50) for n in range(100)]
plt.axis([-100, 100, -100, 100])
plt.scatter(x, y, marker="x")
plt.show()

# %%
import random 
import matplotlib.pyplot as plt 
data = [random.normalvariate(0,10) for n in range(1000)]
plt.title("Hisogram")
plt.hist(data, bins=50)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt 
x = np.arange(-8, 8, 0.01)
y1 =3*x+5
y2 = x**2
plt.title("y=f(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt 
x, y = datasets.make_regression(n_samples=300, n_features=1, noise=20)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
e = linear_model.LinearRegression()
e.fit(x_train, y_train)
print(f"回帰係数は{e.coef_}です。")
print(f"切片は{e.intercept_}です。")
y_pred = e.predict(x_test)
print(f"学習データによる決定係数は{e.score(x_train, y_train)}です。")
print(f"テストデータによる決定係数は{e.score(x_test, y_test)}です。")
plt.scatter(x_train, y_train, label="train")
plt.scatter(x_test, y_test, label="test")
plt.plot(x_test, y_pred, color="magenta")
plt.legend()
plt.show()
# Out:
# 回帰係数は[54.81835178]です。
# 切片は-1.906531904059313です。
# 学習データによる決定係数は0.8944376720034514です。
# テストデータによる決定係数は0.8635068392990841です。

# %%
from sklearn import datasets
from sklearn import cluster
import matplotlib.pyplot as plt 
data, label = datasets.make_blobs(n_samples=1000, n_features=2, centers=8, cluster_std=10)
e = cluster.KMeans(n_clusters=8)
e.fit(data)
print(e.labels_)
print(e.cluster_centers_)
plt.scatter(data[:,0], data[:,1], marker="o", c=e.labels_, edgecolor="k")
plt.scatter(e.cluster_centers_[:,0], e.cluster_centers_[:,1], marker="x")
plt.show()
# Out:
# [7 5 0 0 4 1 0 1 2 3 5 6 2 3 2 7 7 0 6 5 2 0 6 7 6 6 1 4 7 7 0 2 0 7 3 6 3
#  3 6 2 5 2 3 5 7 6 2 4 2 6 2 5 0 2 5 2 3 1 6 2 6 5 2 5 1 6 6 2 2 2 2 7 5 5
#  6 5 6 4 6 2 3 6 1 5 4 5 6 5 5 3 6 5 6 5 7 2 6 2 2 4 6 5 4 1 4 5 6 0 2 2 4
#  3 3 2 2 6 3 1 3 7 7 2 6 1 2 0 5 7 2 7 6 2 6 5 2 6 2 2 1 2 6 0 6 5 3 6 6 5
#  0 5 2 6 4 2 5 5 3 5 5 0 6 5 4 2 7 6 6 2 7 2 4 4 6 7 1 1 7 3 6 4 1 3 5 6 2
#  0 1 5 2 6 2 4 7 3 1 3 5 3 4 3 1 2 6 2 2 6 5 7 2 5 5 5 2 6 5 2 2 6 5 2 4 2
#  6 1 6 2 6 6 7 7 3 4 1 5 6 1 2 6 2 0 7 5 5 3 0 5 6 0 4 6 7 3 6 3 4 2 6 5 6
#  5 6 6 2 7 6 2 6 7 3 1 1 6 6 2 2 6 2 0 1 6 2 2 7 6 3 4 7 0 6 7 7 7 0 1 3 1
#  1 1 2 1 4 4 5 2 6 2 0 2 5 1 7 2 2 6 2 5 4 0 3 5 0 4 7 1 4 4 5 0 0 7 4 6 2
#  7 7 7 5 1 2 5 6 3 6 3 6 7 7 2 1 5 4 6 6 5 5 3 6 5 0 1 4 6 6 6 3 5 5 2 4 0
#  2 6 6 6 2 5 5 5 5 3 4 5 4 5 6 4 3 5 5 1 2 0 4 1 2 4 5 7 7 7 7 6 4 6 2 2 2
#  6 5 7 2 4 5 6 2 1 4 5 2 6 6 7 5 6 2 6 3 2 5 5 5 4 0 6 0 3 5 2 5 3 5 3 1 0
# ...
